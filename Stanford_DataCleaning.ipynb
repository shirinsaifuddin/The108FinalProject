# %%
import pandas as pd

# %%
data = pd.read_csv('CA_2013_onwards.csv')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#                 id state   stop_date  stop_time location_raw  \
# 0  CA-2013-0000001    CA  2013-01-01        NaN    San Diego
# 1  CA-2013-0000002    CA  2013-01-01        NaN    San Diego
# 2  CA-2013-0000003    CA  2013-01-01        NaN    San Diego
# 3  CA-2013-0000004    CA  2013-01-01        NaN    San Diego
# 4  CA-2013-0000005    CA  2013-01-01        NaN    San Diego
#
#         county_name  county_fips  fine_grained_location  police_department  \
# 0  San Diego County       6073.0                    NaN                NaN
# 1  San Diego County       6073.0                    NaN                NaN
# 2  San Diego County       6073.0                    NaN                NaN
# 3  San Diego County       6073.0                    NaN                NaN
# 4  San Diego County       6073.0                    NaN                NaN
#
#   driver_gender    ...    driver_race                           violation_raw  \
# ...

# %%
data
# Out:
#                       id state   stop_date  stop_time       location_raw  \
# 0        CA-2013-0000001    CA  2013-01-01        NaN          San Diego
# 1        CA-2013-0000002    CA  2013-01-01        NaN          San Diego
# 2        CA-2013-0000003    CA  2013-01-01        NaN          San Diego
# 3        CA-2013-0000004    CA  2013-01-01        NaN          San Diego
# 4        CA-2013-0000005    CA  2013-01-01        NaN          San Diego
# 5        CA-2013-0000006    CA  2013-01-01        NaN          San Diego
# 6        CA-2013-0000007    CA  2013-01-01        NaN          San Diego
# 7        CA-2013-0000008    CA  2013-01-01        NaN          San Diego
# 8        CA-2013-0000009    CA  2013-01-01        NaN          San Diego
# 9        CA-2013-0000010    CA  2013-01-01        NaN          San Diego
# 10       CA-2013-0000011    CA  2013-01-01        NaN          Santa Ana
# 11       CA-2013-0000012    CA  2013-01-01        NaN          Santa Ana
# ...

# %%
#drop "id", "stop_time", "fine_grained_location", "county_flips", "police_department", "ethnicity", "violation_raw"
#      "search_conducted", "search_type_raw", "search_type", "contraband_found", "stop_oucome",

# %%
data.rename(index=str, columns={"stop_date": "year", "location_raw": "city", "county_name": "County Name", 
                                "driver_gender": "Driving Gender", "driver_race": "Driving Race", 
                                "is_arrested": "Arrested"})
# Out:
#                       id state        year  stop_time               city  \
# 0        CA-2013-0000001    CA  2013-01-01        NaN          San Diego
# 1        CA-2013-0000002    CA  2013-01-01        NaN          San Diego
# 2        CA-2013-0000003    CA  2013-01-01        NaN          San Diego
# 3        CA-2013-0000004    CA  2013-01-01        NaN          San Diego
# 4        CA-2013-0000005    CA  2013-01-01        NaN          San Diego
# 5        CA-2013-0000006    CA  2013-01-01        NaN          San Diego
# 6        CA-2013-0000007    CA  2013-01-01        NaN          San Diego
# 7        CA-2013-0000008    CA  2013-01-01        NaN          San Diego
# 8        CA-2013-0000009    CA  2013-01-01        NaN          San Diego
# 9        CA-2013-0000010    CA  2013-01-01        NaN          San Diego
# 10       CA-2013-0000011    CA  2013-01-01        NaN          Santa Ana
# 11       CA-2013-0000012    CA  2013-01-01        NaN          Santa Ana
# ...

# %%
data.drop(columns =['id', 'stop_time', 'fine_grained_location', 'county_fips', 'police_department', 'ethnicity', 
                    'violation_raw', 'search_conducted', 'search_type_raw', 'search_type', 'contraband_found', 
                    'stop_outcome'])
# Out:
#         state   stop_date       location_raw            county_name  \
# 0          CA  2013-01-01          San Diego       San Diego County
# 1          CA  2013-01-01          San Diego       San Diego County
# 2          CA  2013-01-01          San Diego       San Diego County
# 3          CA  2013-01-01          San Diego       San Diego County
# 4          CA  2013-01-01          San Diego       San Diego County
# 5          CA  2013-01-01          San Diego       San Diego County
# 6          CA  2013-01-01          San Diego       San Diego County
# 7          CA  2013-01-01          San Diego       San Diego County
# 8          CA  2013-01-01          San Diego       San Diego County
# 9          CA  2013-01-01          San Diego       San Diego County
# 10         CA  2013-01-01          Santa Ana          Orange County
# 11         CA  2013-01-01          Santa Ana          Orange County
# 12         CA  2013-01-01          Santa Ana          Orange County
# ...
